# %%
import pandas as pd
import numpy as np
import math

# %%
np.exp(3)
np.log(math.e)
# Out:
# np.float64(1.0)

# %% [markdown]
# # np indexing

# %%
# the shape which ypu enter the shape you 'll get

test=np.array([
    [2,3,4,5,6],
    [2,3,4,51,76],
    [54,75,90,17,54]
])
test[[[0],[2]],[[3],[4]]]
# Out:
# array([[ 5],
#        [54]])

# %%
print(np.zeros((2,2)))
print(np.ones((2,2)))
print(np.arange(8))
print(np.arange(2,8,2))
print(np.arange(2,8,3))
# Out:
# [[0. 0.]
#  [0. 0.]]
# [[1. 1.]
#  [1. 1.]]
# [0 1 2 3 4 5 6 7]
# [2 4 6]
# [2 5]

# %%
print(test.ndim)
print(test.dtype)
print(test.T)
a=np.array([2,4,5,6])
print(a.ndim)
# Out:
# 2
# int64
# [[ 2  2 54]
#  [ 3  3 75]
#  [ 4  4 90]
#  [ 5 51 17]
#  [ 6 76 54]]
# 1

# %%
arr=np.array([3,4,5,6,1,23,43,2134,12])
idx=[True,False,True,False,True,True,True,False,False,]
print(arr[idx])
# Out:
# [ 3  5  1 23 43]

# %%
print(arr[arr>3])
# Out:
# [   4    5    6   23   43 2134   12]

# %%
op=np.array([[2,4,6,2],[32,54,13,2345],[13,5,13,4]])
op[:,[True,False,False,True]]
# Out:
# array([[   2,    2],
#        [  32, 2345],
#        [  13,    4]])

# %%
A=np.array([[2,3,4],[2,4,6]])
B=np.array([[21,43,13],[21,4,1],[3,7,8]])
print(np.matmul(A,B))
print(A@B)
# Out:
# [[117 126  61]
#  [144 144  78]]
# [[117 126  61]
#  [144 144  78]]

# %% [markdown]
# # Pandas

# %%
df1=pd.DataFrame({
    "id":["01","02","03","04"],
    "name":["Salem","Ahmed","Ali","Sief"],
    "City":["Cairo","Giza","Fayoum","Paris"],
        },index=[1,2,3,4])

df1
# Out:
#    id   name    City
# 1  01  Salem   Cairo
# 2  02  Ahmed    Giza
# 3  03    Ali  Fayoum
# 4  04   Sief   Paris

# %%
print(df1.at[4,"name"])
print(df1.iat[3,1])
# Out:
# Sief
# Sief

# %%
df2=pd.DataFrame({
    "id":["01","02","03","05"],
    "name":["Salem","Ahmed","Ali","Mohamed"],
    "Grades":[14,18,20,33],
        },index=[1,2,3,4])

# %%
pd.merge(df1,df2)
# Out:
#    id   name    City  Grades
# 0  01  Salem   Cairo      14
# 1  02  Ahmed    Giza      18
# 2  03    Ali  Fayoum      20

# %%
pd.merge(df1,df2,how="outer")
# Out:
#    id     name    City  Grades
# 0  01    Salem   Cairo    14.0
# 1  02    Ahmed    Giza    18.0
# 2  03      Ali  Fayoum    20.0
# 3  04     Sief   Paris     NaN
# 4  05  Mohamed     NaN    33.0

# %%
pd.merge(df1,df2,how="left")
# Out:
#    id   name    City  Grades
# 0  01  Salem   Cairo    14.0
# 1  02  Ahmed    Giza    18.0
# 2  03    Ali  Fayoum    20.0
# 3  04   Sief   Paris     NaN

# %%
pd.merge(df1,df2,how="right")
# Out:
#    id     name    City  Grades
# 0  01    Salem   Cairo      14
# 1  02    Ahmed    Giza      18
# 2  03      Ali  Fayoum      20
# 3  05  Mohamed     NaN      33

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    id   name    City  id     name  Grades
# 1  01  Salem   Cairo  01    Salem      14
# 2  02  Ahmed    Giza  02    Ahmed      18
# 3  03    Ali  Fayoum  03      Ali      20
# 4  04   Sief   Paris  05  Mohamed      33

# %%
pd.concat([df1,df2],axis=0)
# Out:
#    id     name    City  Grades
# 1  01    Salem   Cairo     NaN
# 2  02    Ahmed    Giza     NaN
# 3  03      Ali  Fayoum     NaN
# 4  04     Sief   Paris     NaN
# 1  01    Salem     NaN    14.0
# 2  02    Ahmed     NaN    18.0
# 3  03      Ali     NaN    20.0
# 4  05  Mohamed     NaN    33.0

# %%
arr=np.random.normal(50,10,50)

# %%
import requests, zipfile
from io import StringIO
import io

# %%
anime_data = pd.read_csv('MyAnimeList-Database-master/data/anime.csv')
anime_list = pd.read_csv('MyAnimeList-Database-master/data/animelist.csv')
anime_synop = pd.read_csv('MyAnimeList-Database-master/data/anime_with_synopsis.csv')

# %%
anime_data.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# 4          Adventure, Fantasy, Shounen, Supernatural  Beet the Vandel Buster
#
#                       Japanese name   Type Episodes  \
# 0                         カウボーイビバップ     TV       26
# 1                    カウボーイビバップ 天国の扉  Movie        1
# ...

# %%
anime_list.head()
# Out:
#    user_id  anime_id  rating  watching_status  watched_episodes
# 0        0        67       9                1                 1
# 1        0      6702       7                1                 4
# 2        0       242      10                1                 4
# 3        0      4898       0                1                 1
# 4        0        21      10                1                 0

# %%
anime_synop.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1              Action, Drama, Mystery, Sci-Fi, Space
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3  Action, Mystery, Police, Supernatural, Drama, ...
# 4          Adventure, Fantasy, Shounen, Supernatural
#
#                                            sypnopsis
# 0  In the year 2071, humanity has colonized sever...
# 1  other day, another bounty—such is the life of ...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  ches are individuals with special powers like ...
# 4  It is the dark century and the people are suff...

# %%
anime_synop[anime_synop["Score"]=="8.78"]
# Out:
#       MAL_ID                              Name Score  \
# 0          1                      Cowboy Bebop  8.78
# 6673   17074  Monogatari Series: Second Season  8.78
#
#                                                Genres  \
# 0     Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 6673  Mystery, Comedy, Supernatural, Romance, Vampire
#
#                                               sypnopsis
# 0     In the year 2071, humanity has colonized sever...
# 6673  pparitions, oddities, and gods continue to man...

# %%
anime_synop.sort_values(by="Score",ascending=False)
# Out:
#        MAL_ID                                               Name    Score  \
# 1347     1547                                   Obake no Q-tarou  Unknown
# 1439     1656                                    PostPet Momobin  Unknown
# 1512     1739                         Shibawanko no Wa no Kokoro  Unknown
# 1619     1863                            Silk Road Shounen Yuuto  Unknown
# 1808     2073  Hengen Taima Yakou Karura Mau! Sendai Kokeshi ...  Unknown
# ...       ...                                                ...      ...
# 9954    31634                                           Kokuhaku      2.3
# 376       413                                    Hametsu no Mars     2.23
# 13919   38853                                             Ex-Arm     2.18
# 6107    13405                                 Utsu Musume Sayuri     2.01
# 2667     3287                       Tenkuu Danzai Skelter+Heaven     1.85
#
#                                             Genres  \
# ...

# %%
anime_synop[anime_synop["Score"].isin(["Unknown"])]
# Out:
#        MAL_ID                                               Name    Score  \
# 1347     1547                                   Obake no Q-tarou  Unknown
# 1439     1656                                    PostPet Momobin  Unknown
# 1512     1739                         Shibawanko no Wa no Kokoro  Unknown
# 1619     1863                            Silk Road Shounen Yuuto  Unknown
# 1808     2073  Hengen Taima Yakou Karura Mau! Sendai Kokeshi ...  Unknown
# ...       ...                                                ...      ...
# 16209   48481                    Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16210   48483                                       Mieruko-chan  Unknown
# 16211   48488                    Higurashi no Naku Koro ni Sotsu  Unknown
# 16212   48491                        Yama no Susume: Next Summit  Unknown
# 16213   48492                                      Scarlet Nexus  Unknown
#
#                                                   Genres  \
# ...

# %%
anime_data[anime_data["Name"].duplicated()]
# Out:
#        MAL_ID                                               Name    Score  \
# 13540   36296                                        Hinamatsuri     8.21
# 15379   39143                               Youkoso! Ecolo Shima  Unknown
# 17543   48417  Maou Gakuin no Futekigousha: Shijou Saikyou no...  Unknown
# 17544   48418  Maou Gakuin no Futekigousha: Shijou Saikyou no...  Unknown
#
#                                                   Genres English name  \
# 13540  Comedy, Sci-Fi, Seinen, Slice of Life, Superna...  Hinamatsuri
# 15379                                               Kids      Unknown
# 17543                             Magic, Fantasy, School      Unknown
# 17544             Action, Demons, Magic, Fantasy, School      Unknown
#
#                                Japanese name Type Episodes  \
# 13540                                  ヒナまつり   TV       12
# 15379                             ようこそ！ エコロ島  OVA        1
# 17543  魔王学院の不適合者 ～史上最強の魔王の始祖、転生して子孫たちの学校へ通う～   TV  Unknown
# ...

# %%
data=anime_data[anime_data["Score"]!="Unknown"]
data["Score"]=data["Score"].astype(float)

# %%
# data["Score"] = data["Score"].map(
#     lambda x: "Low" if x < 5 else ("Avrage" if x <=7 else "High")
# )

data["Score"]
# Out:
# 0        8.78
# 1        8.39
# 2        8.24
# 3        7.27
# 4        6.98
#          ...
# 17504    6.59
# 17505    7.52
# 17512    6.83
# 17513    4.81
# 17552    6.52
# Name: Score, Length: 12421, dtype: float64

# %%
for i,j in data.groupby("Type"):
    print(i)
    print(j)
    print("\n----------------------------\n")
# Out:
# Movie
#        MAL_ID                                               Name  Score  \
# 1           5                    Cowboy Bebop: Tengoku no Tobira   8.39
# 21         31           Neon Genesis Evangelion: Death & Rebirth   7.45
# 22         32     Neon Genesis Evangelion: The End of Evangelion   8.51
# 24         43                                   Koukaku Kidoutai   8.29
# 27         46  Rurouni Kenshin: Meiji Kenkaku Romantan - Ishi...   7.56
# ...       ...                                                ...    ...
# 16964   42387  Hataraku Saibou!!: Saikyou no Teki, Futatabi. ...   7.18
# 16966   42392  Grisaia: Phantom Trigger The Animation - Starg...   6.90
# 16970   42423                  Date A Bullet: Nightmare or Queen   7.47
# 17134   42836                                   This Is Not Blue   5.87
# 17478   46491          Santa Company: Manatsu no Merry Christmas   5.68
#
#                                                   Genres  \
# ...

# %%
type_1=data.groupby(["Type"])["Score"].mean()
type_1
# Out:
# Type
# Movie      6.497635
# Music      5.882616
# ONA        6.132749
# OVA        6.321410
# Special    6.500507
# TV         6.894178
# Name: Score, dtype: float64

# %%
type_1.loc["Movie"]
# Out:
# np.float64(6.497635101636093)

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,1,1)
x=np.linspace(-10,10,100)
plt.plot(x,np.sin(x))

plt.subplot(2,1,2)

y=np.linspace(-10,10,1000)

plt.plot(y,np.cos(y))

# %%
plt.hist(data["Score"],range=(0,20),bins=5)
# Out:
# (array([   60., 11813.,   548.,     0.,     0.]),
#  array([ 0.,  4.,  8., 12., 16., 20.]),
#  <BarContainer object of 5 artists>)

# %%
df = pd.read_csv("day.csv")

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df["cnt"]
# Out:
# 0       985
# 1       801
# 2      1349
# 3      1562
# 4      1600
#        ...
# 726    2114
# 727    3095
# 728    1341
# 729    1796
# 730    2729
# Name: cnt, Length: 731, dtype: int64

# %%
df["temp"]
# Out:
# 0      0.344167
# 1      0.363478
# 2      0.196364
# 3      0.200000
# 4      0.226957
#          ...
# 726    0.254167
# 727    0.253333
# 728    0.253333
# 729    0.255833
# 730    0.215833
# Name: temp, Length: 731, dtype: float64

# %%
plt.figure(figsize=(13,9))
plt.scatter(df["temp"],df["cnt"],alpha=0.9)
plt.title("Temp Vs Rental")
plt.xlabel("Tempreture",fontsize=16)
plt.ylabel("Rentals",fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid(True)

# %%
df["dteday"]=pd.to_datetime(df["dteday"])
df["dteday"]
# Out:
# 0     2011-01-01
# 1     2011-01-02
# 2     2011-01-03
# 3     2011-01-04
# 4     2011-01-05
#          ...
# 726   2012-12-27
# 727   2012-12-28
# 728   2012-12-29
# 729   2012-12-30
# 730   2012-12-31
# Name: dteday, Length: 731, dtype: datetime64[us]

# %%
edge_bins=[0,1000,2000,3000,4000,5000,6000,7000,8000,9000]

plt.figure(figsize=(8,5))
plt.hist(df["cnt"],bins=edge_bins,edgecolor="black")
plt.tight_layout()

# %%
plt.boxplot(df["cnt"])
plt.boxplot(df["casual"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c469944910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2c469944b90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2c4699447d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c469944e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c469944f50>],
#  'means': []}

# %%
seasons={1: "Winter", 2: "Spring", 3: "Summer", 4: "Autumn"}

df["season"]=df["season"].map(seasons)


# print(casual_avg)

# %%
casual_avg=df.groupby("season")["casual"].mean()

# %%
casual_avg
# Out:
# season
# Autumn     729.112360
# Spring    1106.097826
# Summer    1202.611702
# Winter     334.928177
# Name: casual, dtype: float64

# %%
len(casual_avg)
# Out:
# 4

# %%
width=0.35
x=np.arange(len(casual_avg))
x
# Out:
# array([0, 1, 2, 3])

# %%
casual_avg.values
# Out:
# array([ 729.11235955, 1106.09782609, 1202.61170213,  334.9281768 ])

# %%
registered_avg= df.groupby("season")["registered"].mean()

# %%
plt.bar(x-width/2,casual_avg.values,width)
plt.bar(x+width/2,registered_avg.values,width)
plt.xticks(x,["Winter", "Spring", "Summer", "Fall"])
# Out:
# ([<matplotlib.axis.XTick at 0x2c469d4cf50>,
# ...
#  [Text(0, 0, 'Winter'),
#   Text(1, 0, 'Spring'),
#   Text(2, 0, 'Summer'),
#   Text(3, 0, 'Fall')])

# %%
df["Working Day"]= df["workingday"].map({
    0:"No",
    1:"Yes"
})

# %%
import seaborn as sns

# %%
plt.figure(figsize=(9,5))

sns.barplot(
    data=df,
    x="Working Day",
    y="cnt",
    hue="season",
    estimator=np.mean,
    errorbar=None
)
# print(df.groupby("Working Day")["cnt"].mean())
# Out:
# <Axes: xlabel='Working Day', ylabel='cnt'>

# %%
plt.boxplot(df["cnt"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c46fcf7750>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2c46fcf79d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2c46fcf7610>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c46fcf7c50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c46fcf7d90>],
#  'means': []}

# %%
df["weathersit"].unique()
# Out:
# array([2, 1, 3])

# %%
plt.figure(figsize=(10,6))

sns.boxenplot(
    data=df,
    x="weathersit",
    y="cnt",
    hue="season",
    
)
plt.tight_layout()
plt.show()

# %%
numeric_df = df[[
    "temp",
    "hum",
    "windspeed",
    "casual",
    "registered",
    "cnt"
]]

corr_matrix=numeric_df.corr()
corr_matrix
# Out:
#                 temp       hum  windspeed    casual  registered       cnt
# temp        1.000000  0.126963  -0.157944  0.543285    0.540012  0.627494
# hum         0.126963  1.000000  -0.248489 -0.077008   -0.091089 -0.100659
# windspeed  -0.157944 -0.248489   1.000000 -0.167613   -0.217449 -0.234545
# casual      0.543285 -0.077008  -0.167613  1.000000    0.395282  0.672804
# registered  0.540012 -0.091089  -0.217449  0.395282    1.000000  0.945517
# cnt         0.627494 -0.100659  -0.234545  0.672804    0.945517  1.000000

# %%
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
)
# Out:
# <Axes: >

# %%
def homework (anime_data,metric_column,n):
    
    data=anime_data.sort_values(by=metric_column,ascending=False)
    data=pd.qcut(anime_data[metric_column],q=n)
    
    return data

homework(data,"Score",10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 8
#       4     data=pd.qcut(anime_data,q=n)
#       5
#       6     return data
#       7
# ----> 8 homework(data,"Score",10)
#
# Cell In[98], line 4, in homework(anime_data, metric_column, n)
#       1 def homework (anime_data,metric_column,n):
#       2
#       3     data=anime_data.sort_values(by=metric_column,ascending=False)
# ----> 4     data=pd.qcut(anime_data,q=n)
#       5
#       6     return data
#
# File c:\Users\Access\Desktop\gci_project\myenv\Lib\site-packages\pandas\core\reshape\tile.py:368, in qcut(x, q, labels, retbins, precision, duplicates)
#     364     return x._call_with_func(
#     365         qcut, x=x, q=q, labels=labels, retbins=retbins, precision=precision
#     366     )
#     367 original = x
# --> 368 x_idx = _preprocess_for_cut(x)
#     369 x_idx, _ = _coerce_to_type(x_idx)
# ...
